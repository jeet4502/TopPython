# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
titanic_df=pd.read_csv("./titanic.csv")

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
len(titanic_df.index)
# Out:
# 418

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 titanic_df.rename(columns={'Sibsp: siblings_spouses'})
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5573, in DataFrame.rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5454 def rename(
#    5455     self,
#    5456     mapper: Renamer | None = None,
#    (...)
#    5464     errors: IgnoreRaise = "ignore",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Alter axes labels.
#    5468
#    (...)
#    5571     4  3  6
#    5572     """
# -> 5573     return super()._rename(
#    5574         mapper=mapper,
#    5575         index=index,
#    5576         columns=columns,
#    5577         axis=axis,
#    5578         copy=copy,
#    5579         inplace=inplace,
#    5580         level=level,
#    5581         errors=errors,
#    5582     )
#
# ...
